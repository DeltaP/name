# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('data/processed/USA_names.csv',names=['name','gender','count','year'],header=1)

# %%
data[(data.name == 'Olivia')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
lili = data[(data.name == 'Lily')|
     (data.name == 'Lilian')|
     (data.name == 'Lilyan')|
     (data.name == 'Lilyann')|
     (data.name == 'Lillian')|
     (data.name == 'Lilie')|
     (data.name == 'Lili')|
     (data.name == 'Lilianne')|
     (data.name == 'Lilien')|
     (data.name == 'Liliann')].groupby('year').sum()

# %%
lili.plot(figsize=(10,8))

# %%
data[(data.name == 'Lillian')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
data[(data.name == 'Ivy')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
data[(data.name == 'Irene')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
data[(data.name == 'Nina')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
data[(data.name == 'Alexandria')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
data[(data.name == 'Mia')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
data[data.name == 'Isabell'].plot(x='year',y='count',figsize=(10,8))

# %%
data[(data.name == 'Isabella')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
data[data.name == 'Athena'].plot(x='year',y='count',figsize=(10,8))

# %%
data[(data.name == 'Monique')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
data[data.name == 'Alessandra'].plot(x='year',y='count',figsize=(10,8))

# %%
data[(data.name == 'Athena')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
data[(data.name == 'Leah')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))

# %%
data[(data.name == 'Aria')&(data.gender == 'F')].plot(x='year',y='count',figsize=(10,8))
